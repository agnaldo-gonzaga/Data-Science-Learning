# %%
import pandas as pd

# %%
dados = {
    'Times': ['Corinthians', 'Palmeiras', 'Grêmio', 'São Paulo', 'Vasco'],
    'Partidas_Jogadas': [10, 10, 10, 10, 10],
    'Vitorias': [7, 5, 6, 4, 3],
    'Empates': [2, 3, 1, 3, 22],
    'Derrotas': [1, 2, 3, 5, 8,],
    'Gols_Pro': [22, 18, 16, 14, 10],
    'Gols_Contra': [10, 12, 15, 16, 20]
                 
}

# %%
df = pd.DataFrame(dados)
df
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0  Corinthians                10         7        2         1        22
# 1    Palmeiras                10         5        3         2        18
# 2       Grêmio                10         6        1         3        16
# 3    São Paulo                10         4        3         5        14
# 4        Vasco                10         3       22         8        10
#
#    Gols_Contra
# 0           10
# 1           12
# 2           15
# 3           16
# 4           20

# %%
df['Saldo_Gols'] = df['Gols_Pro'] - df['Gols_Contra']
df
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0  Corinthians                10         7        2         1        22
# 1    Palmeiras                10         5        3         2        18
# 2       Grêmio                10         6        1         3        16
# 3    São Paulo                10         4        3         5        14
# 4        Vasco                10         3       22         8        10
#
#    Gols_Contra  Saldo_Gols
# 0           10          12
# 1           12           6
# 2           15           1
# 3           16          -2
# 4           20         -10

# %%
df['Pontos'] = df['Vitorias'] * 3 + df['Empates'] * 1 
df
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0  Corinthians                10         7        2         1        22
# 1    Palmeiras                10         5        3         2        18
# 2       Grêmio                10         6        1         3        16
# 3    São Paulo                10         4        3         5        14
# 4        Vasco                10         3       22         8        10
#
#    Gols_Contra  Saldo_Gols  Pontos
# 0           10          12      23
# 1           12           6      18
# 2           15           1      19
# 3           16          -2      15
# 4           20         -10      31

# %%
df = df.sort_values(by='Pontos', ascending=False)
df
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 4        Vasco                10         3       22         8        10
# 0  Corinthians                10         7        2         1        22
# 2       Grêmio                10         6        1         3        16
# 1    Palmeiras                10         5        3         2        18
# 3    São Paulo                10         4        3         5        14
#
#    Gols_Contra  Saldo_Gols  Pontos
# 4           20         -10      31
# 0           10          12      23
# 2           15           1      19
# 1           12           6      18
# 3           16          -2      15

# %%
df.to_excel('D:/Area de trabalho/Data-Science-Learning/02-Python/Base-de-dados/campeonato_futebol.xlsx')
