# %% [markdown]
# #  Manipulação de Dados com Pandas: Cria Json
# Este notebook registra o aprendizado de fundamentos da biblioteca **Pandas**
# ---

# %%
import json

# %%
dados_receita = {
    "Receita": [
        {
            "Titulo": "Bolo de Chocolate",
            "Tempo de Preparo": "45 minutos",
            "Porções": "8 porções",
            "Ingredientes": [
                "2 xícaras de farinha de trigo",
                "1 xícara de açúcar",
                "1 xícara de cacau em pó",
                "1 colher de chá de fermento em pó",
                "1/2 colher de chá de bicarbonato de sódio",
                "1/2 colher de chá de sal",
                "1 xícara de leite",
                "1/2 xícara de óleo vegetal",
                "2 ovos",
                "1 colher de chá de essência de baunilha"
            ]
        },  # ← vírgula aqui
        {
            "Titulo": "Bolo de Cenoura",
            "Tempo de Preparo": "40 minutos",
            "Porções": "4 porções",
            "Ingredientes": [
                "3 cenouras médias raladas",
                "4 ovos",
                "1 xícara de óleo vegetal",
                "2 xícaras de açúcar",
                "2 e 1/2 xícaras de farinha de trigo",
                "1 colher de sopa de fermento em pó"
            ]
        }
    ]
}

# %%
with open(r"D:\Area de trabalho\Data-Science-Learning\02-Python\Base-de-dados\receitas.json", "w", encoding="utf-8") as file:
    json.dump(dados_receita, file, indent=4, ensure_ascii=False)
